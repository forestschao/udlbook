# %% [markdown]
# <a href="https://colab.research.google.com/github/forestschao/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-ebxoccxg
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-ebxoccxg
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=c5300e3c2b4fda626bc6ff3459f8f88f83ffafd9371155e7e7fbe565c42c5f95
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c0o4w5nb/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    # h1 = self.linear1(x).relu()
    # h2 = self.linear2(h1).relu()
    # h3 = self.linear3(h2).relu()
    # return self.linear4(h3)

    h1 = self.linear1(x)
    h2 = h1 + self.linear2(h1.relu())
    h3 = h2 + self.linear3(h2.relu())
    return self.linear4(h3.relu())

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.617420, train error 62.47,  val loss 1.681287, percent error 65.60
# Epoch     1, train loss 1.292029, train error 48.38,  val loss 1.440085, percent error 55.40
# Epoch     2, train loss 1.097685, train error 40.17,  val loss 1.341560, percent error 51.60
# Epoch     3, train loss 0.919702, train error 33.53,  val loss 1.204144, percent error 47.50
# Epoch     4, train loss 0.787291, train error 28.22,  val loss 1.147025, percent error 44.50
# Epoch     5, train loss 0.681562, train error 24.93,  val loss 1.117244, percent error 41.70
# Epoch     6, train loss 0.615314, train error 21.65,  val loss 1.136542, percent error 42.60
# Epoch     7, train loss 0.522982, train error 19.25,  val loss 1.159455, percent error 43.10
# Epoch     8, train loss 0.428375, train error 14.40,  val loss 1.087644, percent error 38.30
# Epoch     9, train loss 0.379495, train error 12.45,  val loss 1.156730, percent error 39.80
# Epoch    10, train loss 0.342039, train error 11.75,  val loss 1.228763, percent error 39.10
# Epoch    11, train loss 0.276510, train error 8.70,  val loss 1.196482, percent error 37.80
# Epoch    12, train loss 0.252915, train error 8.25,  val loss 1.187220, percent error 37.10
# Epoch    13, train loss 0.225022, train error 7.43,  val loss 1.317974, percent error 37.60
# Epoch    14, train loss 0.168687, train error 5.20,  val loss 1.376395, percent error 38.30
# Epoch    15, train loss 0.119621, train error 3.45,  val loss 1.365280, percent error 36.90
# Epoch    16, train loss 0.132063, train error 4.55,  val loss 1.409423, percent error 35.70
# Epoch    17, train loss 0.077449, train error 1.78,  val loss 1.387643, percent error 35.60
# Epoch    18, train loss 0.093273, train error 2.35,  val loss 1.483085, percent error 36.30
# Epoch    19, train loss 0.041313, train error 0.60,  val loss 1.386415, percent error 32.60
# Epoch    20, train loss 0.017948, train error 0.00,  val loss 1.422487, percent error 33.70
# Epoch    21, train loss 0.011722, train error 0.00,  val loss 1.419900, percent error 33.10
# Epoch    22, train loss 0.009667, train error 0.00,  val loss 1.438601, percent error 33.20
# Epoch    23, train loss 0.008506, train error 0.00,  val loss 1.460014, percent error 33.20
# Epoch    24, train loss 0.007704, train error 0.00,  val loss 1.474283, percent error 33.30
# Epoch    25, train loss 0.007008, train error 0.00,  val loss 1.488209, percent error 33.60
# Epoch    26, train loss 0.006476, train error 0.00,  val loss 1.510138, percent error 33.50
# Epoch    27, train loss 0.006052, train error 0.00,  val loss 1.521520, percent error 34.00
# Epoch    28, train loss 0.005689, train error 0.00,  val loss 1.534410, percent error 33.50
# Epoch    29, train loss 0.005298, train error 0.00,  val loss 1.545436, percent error 33.80
# Epoch    30, train loss 0.005001, train error 0.00,  val loss 1.556385, percent error 33.80
# Epoch    31, train loss 0.004740, train error 0.00,  val loss 1.567782, percent error 33.60
# Epoch    32, train loss 0.004503, train error 0.00,  val loss 1.576171, percent error 34.20
# Epoch    33, train loss 0.004313, train error 0.00,  val loss 1.587389, percent error 33.90
# Epoch    34, train loss 0.004114, train error 0.00,  val loss 1.595248, percent error 33.90
# Epoch    35, train loss 0.003927, train error 0.00,  val loss 1.604058, percent error 33.70
# Epoch    36, train loss 0.003769, train error 0.00,  val loss 1.613003, percent error 33.90
# Epoch    37, train loss 0.003634, train error 0.00,  val loss 1.619253, percent error 33.40
# Epoch    38, train loss 0.003484, train error 0.00,  val loss 1.629033, percent error 33.60
# Epoch    39, train loss 0.003358, train error 0.00,  val loss 1.637765, percent error 33.80
# Epoch    40, train loss 0.003291, train error 0.00,  val loss 1.640354, percent error 33.50
# Epoch    41, train loss 0.003232, train error 0.00,  val loss 1.643566, percent error 33.40
# Epoch    42, train loss 0.003179, train error 0.00,  val loss 1.646909, percent error 33.60
# Epoch    43, train loss 0.003126, train error 0.00,  val loss 1.650129, percent error 33.40
# Epoch    44, train loss 0.003073, train error 0.00,  val loss 1.653761, percent error 33.50
# Epoch    45, train loss 0.003023, train error 0.00,  val loss 1.657821, percent error 33.50
# Epoch    46, train loss 0.002975, train error 0.00,  val loss 1.660340, percent error 33.60
# Epoch    47, train loss 0.002929, train error 0.00,  val loss 1.664311, percent error 33.60
# Epoch    48, train loss 0.002883, train error 0.00,  val loss 1.667959, percent error 33.60
# Epoch    49, train loss 0.002840, train error 0.00,  val loss 1.671832, percent error 33.60
# Epoch    50, train loss 0.002797, train error 0.00,  val loss 1.672969, percent error 33.60
# Epoch    51, train loss 0.002755, train error 0.00,  val loss 1.676626, percent error 33.50
# Epoch    52, train loss 0.002715, train error 0.00,  val loss 1.679407, percent error 33.50
# Epoch    53, train loss 0.002677, train error 0.00,  val loss 1.683243, percent error 33.40
# Epoch    54, train loss 0.002639, train error 0.00,  val loss 1.685301, percent error 33.40
# Epoch    55, train loss 0.002602, train error 0.00,  val loss 1.688396, percent error 33.40
# Epoch    56, train loss 0.002566, train error 0.00,  val loss 1.691234, percent error 33.40
# Epoch    57, train loss 0.002531, train error 0.00,  val loss 1.695376, percent error 33.50
# Epoch    58, train loss 0.002497, train error 0.00,  val loss 1.697709, percent error 33.50
# Epoch    59, train loss 0.002463, train error 0.00,  val loss 1.700390, percent error 33.50
# Epoch    60, train loss 0.002446, train error 0.00,  val loss 1.701688, percent error 33.50
# Epoch    61, train loss 0.002430, train error 0.00,  val loss 1.703297, percent error 33.50
# Epoch    62, train loss 0.002415, train error 0.00,  val loss 1.704148, percent error 33.50
# Epoch    63, train loss 0.002399, train error 0.00,  val loss 1.705717, percent error 33.50
# Epoch    64, train loss 0.002384, train error 0.00,  val loss 1.707378, percent error 33.50
# Epoch    65, train loss 0.002369, train error 0.00,  val loss 1.708621, percent error 33.50
# Epoch    66, train loss 0.002354, train error 0.00,  val loss 1.710138, percent error 33.50
# Epoch    67, train loss 0.002339, train error 0.00,  val loss 1.711230, percent error 33.60
# Epoch    68, train loss 0.002324, train error 0.00,  val loss 1.712562, percent error 33.50
# Epoch    69, train loss 0.002310, train error 0.00,  val loss 1.714074, percent error 33.50
# Epoch    70, train loss 0.002295, train error 0.00,  val loss 1.715406, percent error 33.60
# Epoch    71, train loss 0.002281, train error 0.00,  val loss 1.716464, percent error 33.60
# Epoch    72, train loss 0.002267, train error 0.00,  val loss 1.717933, percent error 33.60
# Epoch    73, train loss 0.002253, train error 0.00,  val loss 1.719185, percent error 33.70
# Epoch    74, train loss 0.002240, train error 0.00,  val loss 1.720403, percent error 33.50
# Epoch    75, train loss 0.002226, train error 0.00,  val loss 1.721885, percent error 33.60
# Epoch    76, train loss 0.002213, train error 0.00,  val loss 1.723023, percent error 33.70
# Epoch    77, train loss 0.002200, train error 0.00,  val loss 1.724220, percent error 33.70
# Epoch    78, train loss 0.002187, train error 0.00,  val loss 1.725815, percent error 33.70
# Epoch    79, train loss 0.002174, train error 0.00,  val loss 1.727004, percent error 33.80
# Epoch    80, train loss 0.002168, train error 0.00,  val loss 1.727626, percent error 33.70
# Epoch    81, train loss 0.002161, train error 0.00,  val loss 1.728148, percent error 33.80
# Epoch    82, train loss 0.002155, train error 0.00,  val loss 1.728750, percent error 33.80
# Epoch    83, train loss 0.002148, train error 0.00,  val loss 1.729370, percent error 33.70
# Epoch    84, train loss 0.002142, train error 0.00,  val loss 1.729699, percent error 33.70
# Epoch    85, train loss 0.002136, train error 0.00,  val loss 1.730563, percent error 33.80
# Epoch    86, train loss 0.002130, train error 0.00,  val loss 1.731142, percent error 33.80
# Epoch    87, train loss 0.002124, train error 0.00,  val loss 1.731807, percent error 33.70
# Epoch    88, train loss 0.002118, train error 0.00,  val loss 1.732519, percent error 33.80
# Epoch    89, train loss 0.002112, train error 0.00,  val loss 1.732877, percent error 33.80
# Epoch    90, train loss 0.002106, train error 0.00,  val loss 1.733871, percent error 33.80
# Epoch    91, train loss 0.002100, train error 0.00,  val loss 1.734131, percent error 33.70
# Epoch    92, train loss 0.002094, train error 0.00,  val loss 1.734938, percent error 33.80
# Epoch    93, train loss 0.002088, train error 0.00,  val loss 1.735324, percent error 33.80
# Epoch    94, train loss 0.002082, train error 0.00,  val loss 1.735890, percent error 33.80
# Epoch    95, train loss 0.002076, train error 0.00,  val loss 1.736570, percent error 33.80
# Epoch    96, train loss 0.002070, train error 0.00,  val loss 1.737341, percent error 33.80
# Epoch    97, train loss 0.002064, train error 0.00,  val loss 1.738141, percent error 33.80
# Epoch    98, train loss 0.002058, train error 0.00,  val loss 1.738327, percent error 33.70
# Epoch    99, train loss 0.002053, train error 0.00,  val loss 1.738995, percent error 33.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
